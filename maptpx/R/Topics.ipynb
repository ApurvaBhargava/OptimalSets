# %%
#install.packages("slam")
#install.packages("maptpx")

# %%
library("slam")
library("maptpx")

# %%
CVEC <- read.csv("eo_cvec_test.csv", header=FALSE)
CVEC <- as.matrix(CVEC)
K <- 5

# %%
fit <- topics(CVEC, 5)
# Out:
# Estimating on a 100 document collection.
# Fitting the 5 topic model.
# log posterior increase: 1861.4, 1631.2, 450.4, 104.4, 29.5, 14, 10.3, 2.9, 2.5, 0.5, 0.3, done.

# %%
fit$omega
# Out:
#         1            2            3            4            5
# doc 1   0.0003804881 0.0003629870 0.0003887559 0.0004963133 0.9983714558
# doc 2   0.0787720082 0.0004294764 0.9194568572 0.0009208929 0.0004207653
# doc 3   0.2427068714 0.7541407385 0.0011033368 0.0011612244 0.0008878289
# doc 4   0.0006958649 0.0007954995 0.9966584394 0.0009816394 0.0008685568
# doc 5   0.7322666818 0.2648367178 0.0008143191 0.0009495948 0.0011326865
# doc 6   0.0024690337 0.9947184369 0.0008444133 0.0009079688 0.0010601473
# doc 7   0.0004053569 0.0004854877 0.9976364545 0.0009509616 0.0005217393
# doc 8   0.0009355387 0.2263843444 0.0010035108 0.0006889765 0.7709876296
# doc 9   0.0002743215 0.0002905386 0.0017313983 0.9973673553 0.0003363862
# doc 10  0.7574551148 0.2406038249 0.0007016873 0.0005767519 0.0006626211
# doc 11  0.1874152568 0.0018212692 0.8021856133 0.0068625398 0.0017153208
# doc 12  0.9941751307 0.0011928126 0.0011437892 0.0026464026 0.0008418649
# ...
