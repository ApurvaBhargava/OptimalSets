# %%
#install.packages("slam")
#install.packages("maptpx")

# %%
library("slam")
library("maptpx")
# Out:
# Warning message:
# "package 'slam' was built under R version 3.6.3"Warning message:
# "package 'maptpx' was built under R version 3.6.3"

# %%
CVEC <- read.csv("eo_cvec_test.csv", header=FALSE)
CVEC <- as.matrix(CVEC)
K <- 5

# %%
fit <- topics(CVEC, 5)
# Out:
# Estimating on a 100 document collection.
# Fitting the 5 topic model.
# log posterior increase: 2019.3, 1357.7, 265.7, 78.4, 34.3, 24.1, 42.7, 20.1, 19, 2.1, 5.4, 0.2, 1, done.

# %%
fit$omega
# Out:
#         1            2            3            4            5
# doc 1   0.0004425067 0.0003565938 0.0003269719 0.9982552606 0.0006186670
# doc 2   0.9977785068 0.0007715144 0.0004078916 0.0004095701 0.0006325170
# doc 3   0.0012613973 0.3387848882 0.6576070429 0.0011485757 0.0011980958
# doc 4   0.9964725649 0.0007522349 0.0007960947 0.0010028819 0.0009762236
# doc 5   0.0008214116 0.9937212925 0.0030922031 0.0015978534 0.0007672393
# doc 6   0.0007595493 0.0016341254 0.9958023565 0.0010987220 0.0007052468
# doc 7   0.9974778156 0.0004299731 0.0004443901 0.0008346493 0.0008131719
# doc 8   0.0009628376 0.0008967598 0.0011749592 0.9961822777 0.0007831656
# doc 9   0.9985180780 0.0002842207 0.0002918767 0.0003617779 0.0005440467
# doc 10  0.0007178769 0.9962114022 0.0015894968 0.0009749734 0.0005062507
# doc 11  0.9411519179 0.0530683639 0.0017510566 0.0017573833 0.0022712783
# doc 12  0.0023128072 0.9947573675 0.0012516623 0.0009502417 0.0007279212
# ...
